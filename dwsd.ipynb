# %%
from get_wsd import get_dotted_wsd, get_wsd

# %%
data = ['我今天在清大的星巴克喝星巴克', '我很喜歡聽柴可夫斯基，可是打柴可夫斯基他會痛', '貝多芬去台大打籃球']

get_wsd(data)
# Out:
#     Lemma Part-of-Speech     Sense_id                      Gloss Confidence
# 0       我             Nh     05238701                     代指說話者。     0.9768
# 1      今天             Nd     07024601           說話者所在的時間參考點的那一天。     0.9999
# 2       在              P     04015702                      引介處所。     0.9999
# 3      清大             Nc  RP:location                     所在的地方。     0.9989
# 4       的             DE     07023408                  列舉相類似的事物。     0.6625
# 5     星巴克             Nb  RP:location                     所在的地方。     0.8737
# 6       喝             VC     05226901    將液體或糊狀的食物經由口中進入體內並吸收養分。     0.9969
# 7     星巴克             Nb   RP:product         文學藝術方面創作的成品;生產的物品。     0.9685
# 8       我             Nh     05238701                     代指說話者。     0.9979
# 9       很            Dfa     05172901                  表超過平常的程度。     1.0000
# 10     喜歡             VK     06532101            對特定對象有正面的經驗與感覺。     1.0000
# ...
